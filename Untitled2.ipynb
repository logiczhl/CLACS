# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('result - 副本.csv')
df
# Out:
#      2020/1/24  2020/1/25  2020/1/26  2020/1/27  2020/1/28  2020/1/29  \
# 0          142        142        142        142        142        142
# 1           62         82         96        125        145        159
# 2           63         66         80         89        101         97
# 3           33         37         39         40         45         45
# 4            1          4          5          7          9         10
# ..         ...        ...        ...        ...        ...        ...
# 301  2020/1/24  2020/1/25  2020/1/26  2020/1/27  2020/1/28  2020/1/29
# 302    16.4115     23.409    41.9805     59.733     78.552    100.458
# 303   34.77783   53.67444   75.82797  109.88868   149.3751  204.04803
# 304          1          1          1          1          1          1
# 305       1489       1814       2359       3025       4695       6050
#
#      2020/1/30  2020/1/31   2020/2/1  2020/2/2  ...  2022/5/22  2022/5/23  \
# ...

# %%
df = np.array(df)

float(df[303][0])
# Out:
# 34.77783

# %%
for i in range(301):
    for j in range(859):
        df[i][j] = float(df[i][j]) / float(df[305][j])
float(df[0][0])
# Out:
# 0.09536601746138348

# %%
for i in range(301):
    for j in range(859):
        df[i][j] = float(df[i][j]) * float(df[303][j])
df
data1 = pd.DataFrame(df)
data1.to_csv('re2.csv')
